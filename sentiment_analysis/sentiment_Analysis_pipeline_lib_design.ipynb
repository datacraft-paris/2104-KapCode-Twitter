# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import dataiku
from dataiku import pandasutils as pdu

# classic
import time

# data structure
import pandas as pd
import numpy as np

# nlp packages
import nltk
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer

# custom libs
import karmahutils as kut


# ML
import tensorflow as tf
assert tf.__version__ >= "2.0"
from transformers import AutoTokenizer, TFAutoModelForSequenceClassification
from transformers import pipeline


# widgets

import ipywidgets as widgets
from IPython.display import display

# %%
tokenizer = AutoTokenizer.from_pretrained("tblard/tf-allocine", use_fast=True)
model = TFAutoModelForSequenceClassification.from_pretrained("tblard/tf-allocine")
nlp = pipeline('sentiment-analysis', model=model, tokenizer=tokenizer)
# Out:
# All model checkpoint layers were used when initializing TFCamembertForSequenceClassification.
#
# All the layers of TFCamembertForSequenceClassification were initialized from the model checkpoint at tblard/tf-allocine.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFCamembertForSequenceClassification for predictions without further training.

# %%
class Color:   
   GREEN = '\033[92m'
   RED = '\033[91m'
   BOLD = '\033[1m'   
   END = '\033[0m'

button = widgets.Button(
    description='CLASSIFY !',
    button_style='success'
  )

text_area = widgets.Textarea(
    value='',
    placeholder='Type something',
    description='',
    disabled=False
)
output = widgets.Output()

def on_button_clicked(b):
    text = text_area.value
    result = nlp(text)
    prediction = result[0]["label"]
    if prediction == "POSITIVE":   
        color = Color.GREEN    
    else:
        color = Color.RED

    with output:    
        print(Color.BOLD + color + f'{prediction}: ' + Color.END + f'"{text[:50]}"')

button.on_click(on_button_clicked)
display(text_area, button, output)
# Out:
# Textarea(value='', placeholder='Type something')
# Button(button_style='success', description='CLASSIFY !', style=ButtonStyle())
# Output()

# %% [markdown]
# ### cleaning laure
# ```python
#
#
# def clean (text):
#     tokenized = word_tokenize(text) # Tokenize
#     words_only = [word for word in tokenized if word.isalpha()] # Remove numbers
#     stop_words = set(stopwords.words('french')) # Make stopword list
#     without_stopwords = [word for word in words_only if not word in stop_words] # Remove Stop Words
#     lemma=WordNetLemmatizer() # Initiate Lemmatizer
#     lemmatized = [lemma.lemmatize(word) for word in without_stopwords] # Lemmatize
#     return lemmatized
#
# # Apply to all texts
# df['tweet'] = df['tweet'].apply(clean)
# # La fonction clean renvoyant une liste, je transforme cette liste en string
# df['tweet'] = df['tweet'].apply(lambda x: ' '.join(map(str, x)))
# ```

# %%
def load_data(first_extract='mediaVaccination', second_extract='dataVaccination5G', format='dss'):
    media_df=kut.load_dataset(first_extract) if not format=="csv" else pd.read_csv(first_extract)
    media_df=media_df.drop('id',axis=1).set_index('status_id')
    print('media df shape',media_df.shape)
    data_df=kut.load_dataset(second_extract) if not format=="csv" else pd.read_csv(second_extract)
    data_df.set_index('status_id',inplace=True)
    print('data df shape',data_df.shape)
    original_size=len(data_df)
    print('joining')
    data_df=data_df.join(media_df).reset_index()
    print(len(data_df),len(data_df)==original_size)
    print(data_df.shape)
    return data_df
data_df=load_data()
data_df.sample()
# Out:
# 2021-06-09 14:54:01.698713 loading mediaVaccination
# df mediaVaccination loaded: 65882 in 0:00:00.640220
# media df shape (65882, 11)
# 2021-06-09 14:54:02.358922 loading dataVaccination5G
# df dataVaccination5G loaded: 193209 in 0:00:04.941109
# data df shape (193209, 31)
# joining
# 193209 True
# (193209, 43)
#                  status_id     id          pseudo                                              tweet             tweet_date                                          tweet_url     tweet_hashtags tweet_urls   tweet_mentions                                    tweet_formatted  is_rt  retweeted_status_id retweeted_screen_name place_url place_name place_full_name place_type country country_code geo_coords coords_coords              bbox_coords                       name location description  followers_count  friends_count  listed_count  statuses_count  favourites_count   account_created_at profile_expanded_url urls_url urls_t.co urls_expanded_url media_url media_t.co media_expanded_url media_type ext_media_url ext_media_t.co ext_media_expanded_url  ext_media_type
# 61379  1245795721229389824  61380  fatihabadaoui2  RT @collCartonJaune Vu le rejet idéologique de...  2020-04-02 19:30:20.0  http://twitter.com/fatihabadaoui2/statuses/124...  chloroquine|COVID        NaN  collCartonJaune  rt @collcartonjaune vu le rejet ideologique de...   True         1.245640e+18       collCartonJaune       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA  badaoui (RN#MLP_officiel)      NaN         NaN           1360.0         4315.0           3.0         13729.0            6782.0  2015-12-26 17:35:47                  NaN      NaN       NaN               NaN       NaN        NaN                NaN        NaN           NaN            NaN                    NaN             NaN

# %%
def clean_tweets(data,tweet_column='tweet',method='laure',clean_column=None):
    kut.display_message('cleaning tweet column','name: '+tweet_column)
    if clean_column is None :
        clean_column=tweet_column
    print('output',clean_column)
    start=kut.yet()
    def clean (text):
        tokenized = word_tokenize(text) # Tokenize
        words_only = [word for word in tokenized if word.isalpha()] # Remove numbers
        stop_words = set(stopwords.words('french')) # Make stopword list
        without_stopwords = [word for word in words_only if not word in stop_words] # Remove Stop Words
        lemma=WordNetLemmatizer() # Initiate Lemmatizer
        lemmatized = [lemma.lemmatize(word) for word in without_stopwords] # Lemmatize
        return ' '.join([str(X) for X in lemmatized])

    # Apply to all texts
    data[clean_column] = data[tweet_column].apply(clean)
    kut.job_done(start=start)
    return data
data_df=clean_tweets(data= data_df,clean_column='lemmatizedTweet')
data_df.sample()
# Out:
# *************************
# * cleaning tweet column *
# * name: tweet           *
# *************************
# output lemmatizedTweet
# job done in 0:02:18.364897
#                  status_id     id          pseudo                                              tweet             tweet_date                                          tweet_url tweet_hashtags tweet_urls tweet_mentions                                    tweet_formatted  is_rt  retweeted_status_id retweeted_screen_name place_url place_name place_full_name place_type country country_code geo_coords coords_coords              bbox_coords                               name location                                        description  followers_count  friends_count  listed_count  statuses_count  favourites_count   account_created_at profile_expanded_url urls_url urls_t.co urls_expanded_url media_url media_t.co media_expanded_url media_type ext_media_url ext_media_t.co ext_media_expanded_url  ext_media_type                                    lemmatizedTweet
# 19924  1329402193502478336  19925  barbarafleuret  @AdeSouzy @thomas_pennec Parce que ce vaccin n...  2020-11-19 12:32:36.0  http://twitter.com/barbarafleuret/statuses/132...            NaN        NaN       AdeSouzy  @adesouzy @thomas_pennec parce que ce vaccin n...  False                  NaN                   NaN       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA  barbara<U+0001F54A>libre-penseuse   france  <U+0001F6AB>je bloque tous les trolls : insult...            356.0          339.0           1.0          4896.0           11368.0  2010-02-20 10:56:35                  NaN      NaN       NaN               NaN       NaN        NaN                NaN        NaN           NaN            NaN                    NaN             NaN  AdeSouzy Parce vaccin inocule virus atténué co...

# %%
initial_weights = model.get_weights()
model.summary()
# Out:
# Model: "tf_camembert_for_sequence_classification_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# roberta (TFRobertaMainLayer) multiple                  110031360
# _________________________________________________________________
# classifier (TFRobertaClassif multiple                  592130
# =================================================================
# Total params: 110,623,490
# Trainable params: 110,623,490
# Non-trainable params: 0
# _________________________________________________________________

# %%
def predict_sentiments(text):
    result = nlp(text)[0]
    return pd.Series({'sentiment_label':result['label'],'sentiment_score':result['score']} )
test_entry=data_df.sample().iloc[0]
test={'lemme' :test_entry.lemmatizedTweet , 'text': test_entry.tweet}
print(test['text'])
print('--')
print(test['lemme'])
predict_sentiments(test['lemme'])
# Out:
# @HugoMacaire Y’a des puces dans le vaccin qui vont permettre de nous pister mec t’es pas du tout au courant...
# --
# HugoMacaire Y a puce vaccin vont permettre pister mec tout courant
# sentiment_label    NEGATIVE
# sentiment_score    0.685215
# dtype: object

# %%
nlp(['this is a text','this is another'])
# Out:
# [{'label': 'NEGATIVE', 'score': 0.5376941561698914},
#  {'label': 'NEGATIVE', 'score': 0.5078697204589844}]

# %%
start=kut.yet()
test_data=data_df.sample(10)
result=nlp(test_data.lemmatizedTweet.tolist())
kut.job_done(start=start)
pd.DataFrame(result)
# Out:
# job done in 0:00:01.394868
#       label     score
# 0  POSITIVE  0.784953
# 1  POSITIVE  0.553782
# 2  NEGATIVE  0.733865
# 3  NEGATIVE  0.690407
# 4  POSITIVE  0.724882
# 5  POSITIVE  0.733601
# 6  POSITIVE  0.504995
# 7  POSITIVE  0.562934
# 8  NEGATIVE  0.639648
# 9  NEGATIVE  0.657389

# %%
def split_me(data,batch_size=2):
    return [df for g,df in data.groupby(np.arange(len(data))//batch_size)]
test_data=data_df.sample(10).reset_index()
split_me(test_data)[-1]
# Out:
#     index            status_id      id      pseudo                                              tweet             tweet_date                                          tweet_url tweet_hashtags               tweet_urls  tweet_mentions                                    tweet_formatted  is_rt  retweeted_status_id retweeted_screen_name place_url place_name place_full_name place_type country country_code geo_coords coords_coords              bbox_coords          name       location                                        description  followers_count  friends_count  listed_count  statuses_count  favourites_count   account_created_at            profile_expanded_url urls_url urls_t.co urls_expanded_url media_url media_t.co media_expanded_url media_type ext_media_url ext_media_t.co ext_media_expanded_url  ext_media_type                                    lemmatizedTweet
# 8  177254  1293283544261890048  177255    ThiasHDR  RT @jaquieja @Geo75Geo SUIVEZ LES LANCEURS D'A...  2020-08-11 20:29:59.0  http://twitter.com/ThiasHDR/statuses/129328354...            NaN  https://t.co/3HgBVlK7Cv        jaquieja  rt @jaquieja @geo75geo suivez les lanceurs d a...   True         1.293278e+18              jaquieja       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA         Thias         France  Family, sport & nature <U+0001F6B5><U+0001F3FB...             25.0          149.0           0.0          1032.0            1809.0  2017-10-07 06:17:56                             NaN      NaN       NaN               NaN       NaN        NaN                NaN        NaN           NaN            NaN                    NaN             NaN  RT jaquieja SUIVEZ LES LANCEURS SURTOUT QUÈBÈC...
# 9   49740  1288370707114741760   49741  DLFParis16  RT @AldoSterone111 Bill Gates evasif quand CBS...  2020-07-29 07:08:08.0  http://twitter.com/DLFParis16/statuses/1288370...            NaN                      NaN  AldoSterone111  rt @aldosterone111 bill gates evasif quand cbs...   True         1.288076e+18        AldoSterone111       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA  DLF Paris 16  Paris, France  #LaPatrieAvantLesPartis <U+0001F499> <U+0001F1...           1992.0         2938.0          25.0        106593.0          174969.0  2009-10-15 20:16:34  http://www.debout-la-france.fr      NaN       NaN               NaN       NaN        NaN                NaN        NaN           NaN            NaN                    NaN             NaN  RT Bill Gates evasif quand CBSN pose question ...

# %%
kut.file_stamp()
# Out:
# '2021-06-11_1114'

# %%
def load_backup(backup_dir,task_name):
    if backup_dir is None :
        return []
    print('loading intermediate backups')
    files=listdir(backup_dir)
    candidat_files =[X for X in files if task_name in X]
    if len(candidat_files) == 0 :
        print('found no backups for task',taskname)
        return []
    batch_tags=list(set([''.join(X.split('_')[-3:-1]) for X in candidat_files]))
    print('found',len(batch_tags),'jobs')
    print(batch_tags)
    print('selected',max(batch_tags))
    
    return []

# %%
from os import listdir
def batch_me(data,instructions,batch_size=100,track_offset=None,with_save_dir=None,with_load_dir=None,task_name='batchedJob'):
    from math import ceil,floor
    
    batch_size=len(data) if batch_size > len(data) else batch_size
    total_batches=ceil(len(data)/batch_size)
    if track_offset is None :
        track_offset = round(0.25*total_batches)
    
    current_batch=0


    kut.display_message('batching',instructions)
    print(floor(len(data)/batch_size),'batches of',batch_size,'rows')
    
    if len(data)%batch_size:
        print('one batch of',len(data)%batch_size,'rows' )
    if track_offset :
        print('track offset every',track_offset,'batch')
    if with_load_dir is True :
            with_load_dir = with_save_dir
    if with_save_dir :
        save_radical=with_save_dir+'_'.join([task_name,kut.file_stamp()])
        print('batch will be saved in:',save_radical+'_*')
    
    if type(instructions) is not list :
        instructions=[instructions]
    #instructions=[X.replace(data,'batch_df') for X in instructions]
    
    
    
    
    treated_stack=load_backup(backup_dir=with_load_dir,task_name=task_name)
    remaining_data=data
    
       
    
    for batch_df in split_me(data=remaining_data,batch_size=batch_size):
        current_batch +=1
        
        for instruction in instructions :
            eval(instruction)
        
        treated_stack.append(batch_df)
        
        
        # intermediate prints and saves
        if not current_batch % track_offset:
            print('done batch',current_batch)
            if with_save_dir:
                save_name='_'.join([save_radical,str(current_batch)])
                current_treated_df=pd.concat(treated_stack,ignore_index=True)  
                current_treated_df.to_csv(save_name)
                print('saved',len(current_treated_df),'rows')
                print(save_name)
        
        
        
    out=pd.concat(treated_stack,ignore_index=True)   
    
    return out
test_data=data_df.sample(30).reset_index()
save_dir='/home/yann/_run-backups/'
instructions=['print(len(batch_df))','print("done")']
batch_me(data=test_data,batch_size=3,instructions=instructions,with_save_dir=save_dir,with_load_dir=True)
# Out:
# **************************************
# * batching                           *
# * print(len(batch_df)) print("done") *
# **************************************
# 10 batches of 3 rows
# track offset every 2 batch
# batch will be saved in: /home/yann/_run-backups/batchedJob_2021-06-11_1157_*
# loading intermediate backups
# found 8 jobs
# ['2021-06-111134', '2021-06-111121', '2021-06-111136', '2021-06-111133', '2021-06-111123', '2021-06-111130', '2021-06-111119', '2021-06-111128']
# selected 2021-06-111136
# 3
# done
# 3
# done
# done batch 2
# saved 6 rows
# /home/yann/_run-backups/batchedJob_2021-06-11_1157_2
# 3
# done
# 3
# done
# done batch 4
# saved 12 rows
# /home/yann/_run-backups/batchedJob_2021-06-11_1157_4
# 3
# done
# 3
# done
# done batch 6
# saved 18 rows
# /home/yann/_run-backups/batchedJob_2021-06-11_1157_6
# 3
# done
# 3
# done
# done batch 8
# saved 24 rows
# /home/yann/_run-backups/batchedJob_2021-06-11_1157_8
# 3
# done
# 3
# done
# done batch 10
# saved 30 rows
# /home/yann/_run-backups/batchedJob_2021-06-11_1157_10
#      index            status_id      id           pseudo                                              tweet             tweet_date                                          tweet_url                                     tweet_hashtags               tweet_urls                        tweet_mentions                                    tweet_formatted  is_rt  retweeted_status_id retweeted_screen_name place_url place_name place_full_name place_type country country_code geo_coords coords_coords              bbox_coords                                               name                                           location                                        description  followers_count  friends_count  listed_count  statuses_count  favourites_count   account_created_at                         profile_expanded_url                       urls_url                urls_t.co                                  urls_expanded_url                                          media_url               media_t.co                                 media_expanded_url media_type                                      ext_media_url           ext_media_t.co                             ext_media_expanded_url  ext_media_type                                    lemmatizedTweet
# 0    19638  1335593632863227909   19639       ballgrot69  RT @Nini_MacBright Le vaccin de Pfizer, il est...  2020-12-06 14:35:10.0  http://twitter.com/ballgrot69/statuses/1335593...                                                NaN                      NaN                        Nini_MacBright  rt @nini_macbright le vaccin de pfizer, il est...   True         1.334933e+18        Nini_MacBright       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA                                         Ballgrot69                                       Lyon, France                                                NaN              9.0          111.0           0.0          6919.0           19144.0  2016-09-09 07:06:16                                          NaN                            NaN                      NaN                                                NaN                                                NaN                      NaN                                                NaN        NaN                                                NaN                      NaN                                                NaN             NaN  RT Le vaccin Pfizer base ARN messager Ça veut ...
# 1   124483  1347525279644848131  124484   Michel78118339  RT @momotchiii La femme de l'obstétricien de 5...  2021-01-08 12:47:17.0  http://twitter.com/Michel78118339/statuses/134...  Pfizer|manifestation|vaccin|obligatoire|NoForc...  https://t.co/pwA04xFF3Z                            momotchiii  rt @momotchiii la femme de l obstetricien de 5...   True         1.347308e+18            momotchiii       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA  Michel <U+0001F1FA><U+0001F1F8> <U+2721><U+FE0...  Switzerland<U+2666><U+FE0F>NY<U+2666><U+FE0F>B...  2020 will be a terrible year <U+0001F648> I fo...           8338.0         8898.0           4.0         78262.0           58235.0  2019-05-12 21:20:13                                          NaN                            NaN                      NaN                                                NaN                                                NaN                      NaN                                                NaN        NaN                                                NaN                      NaN                                                NaN             NaN  RT momotchiii La femme an décédé suite vaccin ...
# 2   188284  1228799794287718402  188285           When_P  RT @bct_julie S’il vous plaît aidez moi à la r...  2020-02-15 21:54:35.0  http://twitter.com/When_P/statuses/12287997942...                                                NaN                      NaN                             bct_julie  rt @bct_julie s il vous plait aidez moi a la r...   True         1.228627e+18             bct_julie       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA                                               Wenn                                                NaN         Je pense pas que ça intéresse grand monde.              7.0          276.0           0.0          3013.0            5059.0  2013-08-06 20:34:29                                          NaN                            NaN                      NaN                                                NaN                                                NaN                      NaN                                                NaN        NaN                                                NaN                      NaN                                                NaN             NaN  RT S plaît aidez retrouvé tiens beaucoup sais ...
# 3   114330  1332459451010469888  114331         mado1406  RT @ADv_in21 Que fait la Justice de NOTRE pays...  2020-11-27 23:01:03.0  http://twitter.com/mado1406/statuses/133245945...                                                NaN  https://t.co/IGOF14G7BG  ADv_in21| DIVIZIO1,| OSTERElizabeth1  rt @adv_in21 que fait la justice de notre pays...   True         1.332066e+18              ADv_in21       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA                                                ISA                                                NaN  Mensonges permanents, cupidité, corruption, pe...            608.0          943.0           0.0         19281.0           32420.0  2020-01-01 14:09:20                                          NaN                            NaN                      NaN                                                NaN                                                NaN                      NaN                                                NaN        NaN                                                NaN                      NaN                                                NaN             NaN  RT Que fait Justice NOTRE pay QUI va être mesu...
# 4   156831  1334865006056370176  156832    reinfocitoyen  RT @Zyrs10 <U+0001F1FA><U+0001F1F8>RETWEET! Tr...  2020-12-04 14:19:52.0  http://twitter.com/reinfocitoyen/statuses/1334...                                                NaN  https://t.co/i1M5FwS5dg                                Zyrs10  rt @zyrs10 retweet! trump envisageait une comm...   True         1.334677e+18                Zyrs10       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA                                      Reinfocitoyen                                                NaN  La presse a un pouvoir de l'image si puissant ...            566.0         1080.0           3.0          2419.0            3348.0  2020-11-12 23:12:42                                          NaN                            NaN                      NaN                                                NaN                                                NaN                      NaN                                                NaN        NaN                                                NaN                      NaN                                                NaN             NaN  RT RETWEET Trump envisageait commission sécuri...
# 5    50593  1287318706406776832   50594   dominicvasseur  RT @Planetes360 La planète Gates qui mène de l...  2020-07-26 09:27:51.0  http://twitter.com/dominicvasseur/statuses/128...                                                NaN  https://t.co/yry19pzpKX                           Planetes360  rt @planetes360 la planete gates qui mene de l...   True         1.287314e+18           Planetes360       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA                                                 DV                                  Marseille /France                                                NaN            538.0          462.0          67.0        112539.0          130573.0  2013-01-15 17:23:28                                          NaN                            NaN                      NaN                                                NaN                                                NaN                      NaN                                                NaN        NaN                                                NaN                      NaN                                                NaN             NaN  RT La planète Gates mène santé identification ...
# 6   101103  1354664746985922561  101104       languillem  RT @NicolasPichot6 <U+0001F534>Bill Gates: Les...  2021-01-28 05:36:58.0  http://twitter.com/languillem/statuses/1354664...                                                NaN  https://t.co/MHqgW0Ta0k              NicolasPichot6| ADv_in21  rt @nicolaspichot6 bill gates: les passeports ...   True         1.354577e+18        NicolasPichot6       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA                                    ludimi Matr 111                                             france                                                NaN           6733.0         6262.0        1188.0       1194254.0          479942.0  2012-10-25 17:38:56                                          NaN                            NaN                      NaN                                                NaN                                                NaN                      NaN                                                NaN        NaN                                                NaN                      NaN                                                NaN             NaN  RT Bill Gates Les passeports vaccination COVID...
# 7   180069  1245658451184717824  180070        ToonyBang  RT @LePetitGuenon Bill Gates demande un "certi...  2020-04-02 10:24:52.0  http://twitter.com/ToonyBang/statuses/12456584...                                                NOM  https://t.co/nlbst4XPZt                         LePetitGuenon  rt @lepetitguenon bill gates demande un "certi...   True         1.245503e+18         LePetitGuenon       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA                         ynooT <U+0001F5FA><U+FE0F>                                                NaN  Notre patience touche à sa fin, votre bail aussi.            204.0          789.0           3.0         11671.0           15869.0  2012-10-27 12:01:52                                          NaN                            NaN                      NaN                                                NaN                                                NaN                      NaN                                                NaN        NaN                                                NaN                      NaN                                                NaN             NaN  RT LePetitGuenon Bill Gates demande certificat...
# 8   120527  1339157414109736960  120528       Math_omane  @AgnurWild Oui le vaccin rend allergique et t'...  2020-12-16 10:36:22.0  http://twitter.com/Math_omane/statuses/1339157...                                                NaN                      NaN                             AgnurWild  @agnurwild oui le vaccin rend allergique et t ...  False                  NaN                   NaN       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA                                     Daddy Math0,1%                                     Dans Ta Classe  Prof de points G et de plans Q. J'ai le poil s...           3276.0          107.0          44.0         36689.0            8358.0  2014-01-12 11:20:03                                          NaN                            NaN                      NaN                                                NaN                                                NaN                      NaN                                                NaN        NaN                                                NaN                      NaN                                                NaN             NaN  AgnurWild Oui vaccin rend allergique puce rept...
# 9   139383  1239438574535278593  139384  OlivierFraudeau  RT @RaderSerge Plus on tripote les virus dans ...  2020-03-16 06:29:18.0  http://twitter.com/OlivierFraudeau/statuses/12...                                                NaN                      NaN                            RaderSerge  rt @raderserge plus on tripote les virus dans ...   True         1.239279e+18            RaderSerge       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA                                   Olivier Fraudeau                                             France  Anti géo-ingénierie, anti Haarp, anti théories...           1539.0         4819.0          31.0         16661.0            5801.0  2015-04-03 16:37:54                                          NaN                            NaN                      NaN                                                NaN                                                NaN                      NaN                                                NaN        NaN                                                NaN                      NaN                                                NaN             NaN  RT RaderSerge Plus tripote virus centre aussi ...
# 10   94755  1344212874374295555   94756    KamkamLerouge  RT @1Chenapan Je n'ai aucune compétence médica...  2020-12-30 09:24:58.0  http://twitter.com/KamkamLerouge/statuses/1344...                                                NaN                      NaN                             1Chenapan  rt @1chenapan je n ai aucune competence medica...   True         1.344212e+18             1Chenapan       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA             KamkamLerouge <U+0001F1EB><U+0001F1F7>                         Nouvelle-Aquitaine, France  La liberté des uns s'arrête là où commence cel...           1269.0            0.0           0.0         43064.0           81376.0  2018-02-20 14:03:00                                          NaN                            NaN                      NaN                                                NaN                                                NaN                      NaN                                                NaN        NaN                                                NaN                      NaN                                                NaN             NaN  RT Je aucune compétence médicale si peux aider...
# 11   90378  1313779791556993037   90379   Joelle30792095  RT @AldoSterone111 Bill Gates promet un retour...  2020-10-07 09:54:45.0  http://twitter.com/Joelle30792095/statuses/131...                                                NaN  https://t.co/0Nyikzg6uG                        AldoSterone111  rt @aldosterone111 bill gates promet un retour...   True         1.313765e+18        AldoSterone111       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA                                                  B                                                NaN                                     #Teampatriotes            516.0          518.0           0.0         38794.0           43933.0  2017-03-05 08:55:32                                          NaN                            NaN                      NaN                                                NaN                                                NaN                      NaN                                                NaN        NaN                                                NaN                      NaN                                                NaN             NaN  RT Bill Gates promet retour a normale fin si v...
# 12   37806  1296354801706586112   37807   clanuitblanche  RT @CorinneReverbel "Au cours de la campagne M...  2020-08-20 07:54:04.0  http://twitter.com/clanuitblanche/statuses/129...                                                NaN                      NaN                       CorinneReverbel  rt @corinnereverbel "au cours de la campagne m...   True         1.296091e+18       CorinneReverbel       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA                                    la nuit blanche                                                NaN  Un simple virus a fait basculer notre monde da...           1164.0          605.0           4.0          8411.0            8204.0  2015-12-02 23:59:30                                          NaN                            NaN                      NaN                                                NaN                                                NaN                      NaN                                                NaN        NaN                                                NaN                      NaN                                                NaN             NaN  RT CorinneReverbel Au cours campagne MenAfriVa...
# 13    6350  1347600377215123456    6351          AJ91000  RT @momotchiii La femme de l'obstétricien de 5...  2021-01-08 17:45:41.0  http://twitter.com/AJ91000/statuses/1347600377...  Pfizer|manifestation|vaccin|obligatoire|NoForc...  https://t.co/pwA04xFF3Z                            momotchiii  rt @momotchiii la femme de l obstetricien de 5...   True         1.347308e+18            momotchiii       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA                                                 JA                                                NaN                                                NaN           1339.0         4666.0           4.0        103304.0           28493.0  2010-03-01 17:24:36                                          NaN                            NaN                      NaN                                                NaN                                                NaN                      NaN                                                NaN        NaN                                                NaN                      NaN                                                NaN             NaN  RT momotchiii La femme an décédé suite vaccin ...
# 14  135537  1313448580787712000  135538       Nicotenn37  @LauraLakitow Pour ceux qui ne savent pas que ...  2020-10-06 11:58:39.0  http://twitter.com/Nicotenn37/statuses/1313448...                                                NaN                      NaN                          LauraLakitow  @lauralakitow pour ceux qui ne savent pas que ...  False                  NaN                   NaN       NaN        NaN             NaN        NaN     NaN          NaN        NaN           NaN                      NaN                                                NaN                                                NaN                                                NaN              NaN            NaN           NaN             NaN               NaN                  NaN                                          NaN    twitter.com/DocteurGonzo4/…  https://t.co/DAi5yi7K7T  https://twitter.com/DocteurGonzo4/status/13125...                                                NaN                      NaN                                                NaN        NaN                                                NaN                      NaN                                                NaN             NaN  LauraLakitow Pour ceux savent Gates a créé cor...
# 15  175520  1316082219467845633  175521        Tchi59000  RT @FranceRsistanc1 La vie ne reviendra à la n...  2020-10-13 18:23:47.0  http://twitter.com/Tchi59000/statuses/13160822...                                                NaN  https://t.co/8K0KYBSUFB      FranceRsistanc1| realDonaldTrump  rt @francersistanc1 la vie ne reviendra a la n...   True         1.316051e+18       FranceRsistanc1       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA                                           swyndauw                                             france                                                NaN             19.0          105.0           0.0          2653.0             321.0  2010-04-15 20:58:19                                          NaN                            NaN                      NaN                                                NaN                                                NaN                      NaN                                                NaN        NaN                                                NaN                      NaN                                                NaN             NaN  RT La vie reviendra normale déploiement deuxiè...
# 16   86536  1258821435524558849   86537       jeanefbey2  @HTohi7 la population ne comprend pas où BigPh...  2020-05-08 18:09:52.0  http://twitter.com/jeanefbey2/statuses/1258821...                                                NaN  https://t.co/9aX1Q60Fzj                                HTohi7  @htohi7 la population ne comprend pas ou bigph...  False                  NaN                   NaN       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA                                             FAIVRE                                                NaN  2021, en plein vent !\nLobbyiste anti-Covid.\n...           1022.0         1794.0           4.0         53539.0           15526.0  2017-10-14 10:51:48                         http://www.jeanef.fr                            NaN                      NaN                                                NaN  http://pbs.twimg.com/tweet_video_thumb/EXg7az-...  https://t.co/9aX1Q60Fzj  https://twitter.com/jeanefbey2/status/12588214...      photo  http://pbs.twimg.com/tweet_video_thumb/EXg7az-...  https://t.co/9aX1Q60Fzj  https://twitter.com/jeanefbey2/status/12588214...             NaN  population comprend où BigPharma veut venir Bi...
# 17   92098  1344561334520860674   92099          jph2110  @LeDanator @MachinaSosa Vu qu on doit tous se ...  2020-12-31 08:29:37.0  http://twitter.com/jph2110/statuses/1344561334...                                                NaN                      NaN                             LeDanator  @ledanator @machinasosa vu qu on doit tous se ...  False                  NaN                   NaN       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA  Jean-Phi <U+0001F489>#promspourlevaccin <U+000...                                                NaN                                                NaN             26.0          267.0           0.0           906.0            1272.0  2014-05-12 17:21:38                                          NaN                            NaN                      NaN                                                NaN                                                NaN                      NaN                                                NaN        NaN                                                NaN                      NaN                                                NaN             NaN  LeDanator MachinaSosa Vu doit tous faire injec...
# 18   97945  1328984478325346305   97946  Krieger66362259  Énigme du Covid-19 : Virus sorti d’un laborato...  2020-11-18 08:52:45.0  http://twitter.com/Krieger66362259/statuses/13...                                                NaN  https://t.co/9amMizjxs3                       wordpressdotcom  énigme du covid 19 : virus sorti d un laborato...  False                  NaN                   NaN       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA                                    Richard Krieger                                             Monaco  Revue de presse quotidienne : « Bien informés ...           5972.0         3637.0          14.0         31263.0           80878.0  2016-12-22 21:15:15  http://www.entrepreneurs-pour-la-France.org  aphadolie.com/2020/11/18/eni…  https://t.co/9amMizjxs3  https://aphadolie.com/2020/11/18/enigme-du-cov...                                                NaN                      NaN                                                NaN        NaN                                                NaN                      NaN                                                NaN             NaN  Énigme Virus sorti laboratoire Vaccin obligato...
# 19  124223  1221921381551611905  124224         MiAyotte  RT @RadioCanadaInfo Non, le coronavirus n’a pa...  2020-01-27 22:22:14.0  http://twitter.com/MiAyotte/statuses/122192138...                                                NaN  https://t.co/ttkMh0gyPH                       RadioCanadaInfo  rt @radiocanadainfo non, le coronavirus n a pa...   True         1.221914e+18       RadioCanadaInfo       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA                                    Michelle Ayotte                                 Shawinigan, Québec             Jeune professionnelle en communication            221.0         1286.0          38.0         17114.0           31982.0  2014-10-17 13:55:55                                          NaN                            NaN                      NaN                                                NaN                                                NaN                      NaN                                                NaN        NaN                                                NaN                      NaN                                                NaN             NaN  RT RadioCanadaInfo Non coronavirus a inventé l...
# 20   35007  1326269304950677506   35008     cherielle100  RT @Yoann2944 @sonjoachim #Covid_19 = grippe 2...  2020-11-10 21:03:37.0  http://twitter.com/cherielle100/statuses/13262...                                           Covid_19                      NaN                             Yoann2944  rt @yoann2944 @sonjoachim #covid_19 = grippe 2...   True         1.326267e+18             Yoann2944       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA                                           sylvie m                                                NaN  Passes ton chemin si tu es un covid-idiot ou G...          15543.0        13712.0         145.0        225205.0           13695.0  2012-05-21 22:07:22                                          NaN                            NaN                      NaN                                                NaN                                                NaN                      NaN                                                NaN        NaN                                                NaN                      NaN                                                NaN             NaN  RT sonjoachim grippe Se grippe masque Non étud...
# 21   58018  1271430747254132736   58019       EricFouque  RT @WikistrikeW Bill Gates dépense 1,6 milliar...  2020-06-12 13:14:46.0  http://twitter.com/EricFouque/statuses/1271430...                                  Santé-psychologie  https://t.co/o2AQz5BpMd                           WikistrikeW  rt @wikistrikew bill gates depense 1,6 milliar...   True         1.271295e+18           WikistrikeW       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA                                        Eric FOUQUE                                                NaN  2022, nous allons changer les choses nous somm...            221.0          457.0           0.0         32211.0           17947.0  2020-02-20 20:07:31                                          NaN                            NaN                      NaN                                                NaN                                                NaN                      NaN                                                NaN        NaN                                                NaN                      NaN                                                NaN             NaN  RT WikistrikeW Bill Gates dépense milliard dol...
# 22  121768  1293600972841914377  121769        Mazenod10  RT @DOMINIQUEJAMAIS L’ancien médecin de Bill G...  2020-08-12 17:31:20.0  http://twitter.com/Mazenod10/statuses/12936009...                                                NaN  https://t.co/XPjivfCFLH                       DOMINIQUEJAMAIS  rt @dominiquejamais l ancien medecin de bill g...   True         1.293108e+18       DOMINIQUEJAMAIS       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA                                            Mazenod                                                NaN                                                NaN           1982.0         3179.0           5.0        401535.0          363681.0  2018-03-26 19:03:52                                          NaN                            NaN                      NaN                                                NaN                                                NaN                      NaN                                                NaN        NaN                                                NaN                      NaN                                                NaN             NaN  RT DOMINIQUEJAMAIS L ancien médecin Bill Gates...
# 23   89198  1275162050826768388   89199       Jimmyred78  RT @ADuferret RETWEET! Trump envisageait une c...  2020-06-22 20:21:38.0  http://twitter.com/Jimmyred78/statuses/1275162...                                                NaN                      NaN                             ADuferret  rt @aduferret retweet! trump envisageait une c...   True         1.275113e+18             ADuferret       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA                                          Jimmy red                       Mantes-la-Jolie, au Maghreb.  Fondamentaux: La conformité avec le réel !  Pa...           1055.0          980.0           2.0         25091.0           30095.0  2011-04-09 10:52:58                                          NaN                            NaN                      NaN                                                NaN                                                NaN                      NaN                                                NaN        NaN                                                NaN                      NaN                                                NaN             NaN  RT ADuferret RETWEET Trump envisageait commiss...
# 24   31930  1311541351243296768   31931      Catyodalune  RT @reseau_internat Le vaccin de Gates propage...  2020-10-01 05:40:00.0  http://twitter.com/Catyodalune/statuses/131154...                                                NaN  https://t.co/8Gpbt0mYYr                       reseau_internat  rt @reseau_internat le vaccin de gates propage...   True         1.311538e+18       reseau_internat       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA                                            Catyoda                                                NaN                                                NaN            412.0         1775.0           0.0         10825.0           24476.0  2018-06-23 07:38:53                                          NaN                            NaN                      NaN                                                NaN                                                NaN                      NaN                                                NaN        NaN                                                NaN                      NaN                                                NaN             NaN  RT Le vaccin Gates propage polio travers Afriq...
# 25   51559  1257044784902004740   51560        dr_remezo  Après le Prix Nobel Montagnier ,Trump et Pompe...  2020-05-03 20:30:06.0  http://twitter.com/dr_remezo/statuses/12570447...                                                NaN                      NaN                                   NaN  apres le prix nobel montagnier ,trump et pompe...  False                  NaN                   NaN       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA                 Dr_RemezoA<U+0001F1E7><U+0001F1EE>                                   Grenoble, France  Cardiology fellow <U+0001F1EB><U+0001F1F7>Prou...           1344.0         1292.0           3.0          2262.0            3892.0  2011-10-31 14:22:58                                          NaN    twitter.com/RFI/status/125…  https://t.co/BjilVREG64  https://twitter.com/RFI/status/125695040868712...                                                NaN                      NaN                                                NaN        NaN                                                NaN                      NaN                                                NaN             NaN  Après Prix Nobel Montagnier Trump Pompeo assur...
# 26   89717  1365008474392961027   89718           jlz069  RT @DP_2020_ POLOGNE Ce docteur, encourageait ...  2021-02-25 18:39:15.0  http://twitter.com/jlz069/statuses/13650084743...                                                NaN  https://t.co/s6EYpQQQ37                              DP_2020_  rt @dp_2020_ pologne ce docteur, encourageait ...   True         1.365007e+18              DP_2020_       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA                                           Jean-Luc                                                NaN  “Le meilleur médecin est la nature : elle guér...             16.0          120.0           0.0          1132.0             400.0  2013-09-17 10:07:51                                          NaN                            NaN                      NaN                                                NaN                                                NaN                      NaN                                                NaN        NaN                                                NaN                      NaN                                                NaN             NaN  RT POLOGNE Ce docteur encourageait a vacciner ...
# 27  163585  1264264567728693249  163586    SantiagoRiva4  RT @MrSowGood Hier j'ai eu un live sur Insta, ...  2020-05-23 18:38:56.0  http://twitter.com/SantiagoRiva4/statuses/1264...                                                NaN  https://t.co/Z8R8lOMRyi                             MrSowGood  rt @mrsowgood hier j ai eu un live sur insta, ...   True         1.264259e+18             MrSowGood       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA                                       SantiagoRiva                                                NaN                                                NaN             14.0          367.0           0.0          7647.0            2654.0  2017-11-07 20:04:16                                          NaN                            NaN                      NaN                                                NaN                                                NaN                      NaN                                                NaN        NaN                                                NaN                      NaN                                                NaN             NaN  RT MrSowGood Hier live Insta sujets franc cfa ...
# 28  113359  1312351578561613834  113360      LyLyyyStyle  Finalement c'est un peu s'qui nous pend au nez...  2020-10-03 11:19:33.0  http://twitter.com/LyLyyyStyle/statuses/131235...                                                NaN                      NaN                                   NaN  finalement c est un peu s qui nous pend au nez...  False                  NaN                   NaN       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA                                           Stayfree                                              paris  Mon pays c'est le monde, ma religion c'est  fa...           1277.0          602.0           4.0         10235.0           29138.0  2012-08-20 15:04:37                                          NaN    twitter.com/HypathieBlog/s…  https://t.co/MHpz6ITsRk  https://twitter.com/HypathieBlog/status/131232...                                                NaN                      NaN                                                NaN        NaN                                                NaN                      NaN                                                NaN             NaN  Finalement peu pend nez ceux refuseront vaccin...
# 29   89838  1365675054101647361   89839            JMFLB  RT @UPR_Asselineau <U+0001F489>Vous reprendrez...  2021-02-27 14:48:00.0  http://twitter.com/JMFLB/statuses/136567505410...                                            vaccin,  https://t.co/fIJKGKQltH                        UPR_Asselineau  rt @upr_asselineau vous reprendrez bien une 3e...   True         1.365661e+18        UPR_Asselineau       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA  Jacques Le Bris Citoyen <U+0001F1EB><U+0001F1F...                                   Lacroix-Falgarde  Bonjour,\nJe suis,\n#JeSuisCharlie #JeSuisMila...           3147.0         4702.0         528.0        179781.0           26869.0  2010-01-31 14:57:45        http://jacques-le-bris.over-blog.com/                            NaN                      NaN                                                NaN                                                NaN                      NaN                                                NaN        NaN                                                NaN                      NaN                                                NaN             NaN  RT Vous reprendrez bien dose vaccin histoire p...

# %%
def add_sentiment_information(data,lemme_column='lemmatizedTweet'):
    kut.display_message('adding sentiment information based on '+ lemme_column)
    print('expected time is 300s/1000rows')
    start=kut.yet()
    lemme_array=data[lemme_column].tolist()
    nlp_df=pd.DataFrame(nlp(lemme_array)).rename(columns={'label':'sentiment_label','score':'sentiment_score'})
    out=data.join(pd.DataFrame(nlp(lemme_array)))
    kut.job_done(start=start)
    return out
test_data=data_df.sample(10).reset_index()
add_sentiment_information(test_data)
# Out:
# *********************************************************
# * adding sentiment information based on lemmatizedTweet *
# *********************************************************
# expected time is 350s/1000rows
# job done in 0:04:49.764419
#       index            status_id      id          pseudo                                              tweet             tweet_date                                          tweet_url                   tweet_hashtags                                       tweet_urls                 tweet_mentions                                    tweet_formatted  is_rt  retweeted_status_id retweeted_screen_name place_url place_name place_full_name place_type country country_code geo_coords coords_coords              bbox_coords                                               name                location                                        description  followers_count  friends_count  listed_count  statuses_count  favourites_count   account_created_at profile_expanded_url              urls_url                urls_t.co             urls_expanded_url media_url media_t.co media_expanded_url media_type ext_media_url ext_media_t.co ext_media_expanded_url  ext_media_type                                    lemmatizedTweet     label     score
# 0    106856  1276236624721035264  106857     LevyLoiseau  RT @RaderSerge Ce vaccin à ARN est une utopie ...  2020-06-25 19:31:37.0  http://twitter.com/LevyLoiseau/statuses/127623...                              NaN                          https://t.co/jjZFoTxzol                     RaderSerge  rt @raderserge ce vaccin a arn est une utopie ...   True         1.276231e+18            RaderSerge       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA                                      @Kliment Levi  Mont-Tremblant, Québec                                          Pitchipoï           1728.0         3151.0          24.0        276595.0          170113.0  2011-10-27 06:54:40                  NaN                   NaN                      NaN                           NaN       NaN        NaN                NaN        NaN           NaN            NaN                    NaN             NaN  RT RaderSerge Ce vaccin ARN utopie idiote Par ...  NEGATIVE  0.888195
# 1     51378  1284347863204601856   51379   DoyonFrancis1  RT @cherielle100 Vaccine Choice Canada poursui...  2020-07-18 04:42:47.0  http://twitter.com/DoyonFrancis1/statuses/1284...                        RDI|polqc  https://t.co/qD8pLlQI8P|https://t.co/Lb09ncqxXX  cherielle100| francoislegault  rt @cherielle100 vaccine choice canada poursui...   True         1.284348e+18          cherielle100       NaN        NaN             NaN        NaN     NaN          NaN        NaN           NaN                      NaN                                                NaN                     NaN                                                NaN              NaN            NaN           NaN             NaN               NaN                  NaN                  NaN                   NaN                      NaN                           NaN       NaN        NaN                NaN        NaN           NaN            NaN                    NaN             NaN  RT Vaccine Choice Canada poursuit VCC affirme ...  NEGATIVE  0.503438
# 2    191238  1247421468964782081  191239        ypuget31  RT @EDeymard Covid-19 : La Fondation Gates va ...  2020-04-07 07:10:28.0  http://twitter.com/ypuget31/statuses/124742146...                              NaN                          https://t.co/QrSJuuciLF       EDeymard| LUsineDigitale  rt @edeymard covid 19 : la fondation gates va ...   True         1.247421e+18              EDeymard       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA                                      Yannick Puget                Toulouse  Directeur Services & Innovation - iMSA #dsi #p...            634.0          622.0         143.0          8023.0           10525.0  2011-08-24 16:08:45                  NaN                   NaN                      NaN                           NaN       NaN        NaN                NaN        NaN           NaN            NaN                    NaN             NaN  RT EDeymard La Fondation Gates va financer usi...  NEGATIVE  0.500366
# 3    134602  1261236632088391680  134603       newsnetfr  [Leonid Savin] Au fou ! ... Bill Gates, Vaccin...  2020-05-15 10:07:00.0  http://twitter.com/newsnetfr/statuses/12612366...                              NaN                          https://t.co/aW5zG1GzLo                            NaN  [leonid savin] au fou ! ... bill gates, vaccin...  False                  NaN                   NaN       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA                                            newsnet                     NaN                                    Avenir du monde             62.0            0.0           0.0         11736.0               0.0  2019-04-20 18:17:05    http://newsnet.fr     newsnet.fr/173921  https://t.co/aW5zG1GzLo      http://newsnet.fr/173921       NaN        NaN                NaN        NaN           NaN            NaN                    NaN             NaN  Leonid Savin Au fou Bill Gates Vaccinations pu...  POSITIVE  0.534847
# 4      8838  1326890310186758144    8839         alixpv1  RT @us_ain j’espère que la puce que le makhzen...  2020-11-12 14:11:17.0  http://twitter.com/alixpv1/statuses/1326890310...                              NaN                                              NaN                         us_ain  rt @us_ain j espere que la puce que le makhzen...   True         1.326856e+18                us_ain       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA                                               Alix                     NaN                                                NaN            161.0          242.0           1.0          1904.0            1743.0  2013-05-16 14:58:42                  NaN                   NaN                      NaN                           NaN       NaN        NaN                NaN        NaN           NaN            NaN                    NaN             NaN  RT espère puce makhzen va injecter mime temp v...  NEGATIVE  0.803570
# ..      ...                  ...     ...             ...                                                ...                    ...                                                ...                              ...                                              ...                            ...                                                ...    ...                  ...                   ...       ...        ...             ...        ...     ...          ...        ...           ...                      ...                                                ...                     ...                                                ...              ...            ...           ...             ...               ...                  ...                  ...                   ...                      ...                           ...       ...        ...                ...        ...           ...            ...                    ...             ...                                                ...       ...       ...
# 995  173565  1314964094521352192  173566    Swiss_Pepita  RT @heidi_news Quel est le rapport entre les r...  2020-10-10 16:20:45.0  http://twitter.com/Swiss_Pepita/statuses/13149...                              NaN                          https://t.co/Fjg5Ndend9                     heidi_news  rt @heidi_news quel est le rapport entre les r...   True         1.314960e+18            heidi_news       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA  Christiane <U+0001F64B> & Lulu the Cat <U+0001...     Rhône-Alpes, France  Le plus souvent on cherche son bonheur comme o...           1969.0         2621.0         185.0        303582.0          226712.0  2012-06-12 15:52:36                  NaN                   NaN                      NaN                           NaN       NaN        NaN                NaN        NaN           NaN            NaN                    NaN             NaN  RT Quel rapport entre réseaux pédophiles Covid...  POSITIVE  0.571888
# 996   43277  1365474226627633153   43278  DagostinoJordi  @TichotB @ADv_in21 @juniorbequille Mot clés po...  2021-02-27 01:29:59.0  http://twitter.com/DagostinoJordi/statuses/136...                              NaN                                              NaN        TichotB| juniorbequille  @tichotb @adv_in21 @juniorbequille mot cles po...  False                  NaN                   NaN       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA                           Robespierre le nettoyeur                  France  Grand reset ou Grand nettoyage\n\nLE CHOIX EST...             82.0          361.0           0.0          2208.0            1301.0  2020-12-29 23:11:26                  NaN                   NaN                      NaN                           NaN       NaN        NaN                NaN        NaN           NaN            NaN                    NaN             NaN  TichotB juniorbequille Mot clés comprendre ID ...  POSITIVE  0.761010
# 997   45855  1260541792677699584   45856     Debeaulieu8  RT @RaderSerge Magistrale intervention de Robe...  2020-05-13 12:05:57.0  http://twitter.com/Debeaulieu8/statuses/126054...                              NaN                          https://t.co/TVzZmksu6d                     RaderSerge  rt @raderserge magistrale intervention de robe...   True         1.259567e+18            RaderSerge       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA                                    Debeaulieu.nour                     NaN  Celui qui se bat peut perdre, celui qui se bat...           1728.0         2804.0           3.0         75955.0           86972.0  2017-03-13 19:58:29                  NaN                   NaN                      NaN                           NaN       NaN        NaN                NaN        NaN           NaN            NaN                    NaN             NaN  RT RaderSerge Magistrale intervention Robert K...  POSITIVE  0.771645
# 998   67488  1258372334269935616   67489  fredmontaigu85  @CNEWS S'il vous plait @CNEWS @BFMTV @TF1LeJT ...  2020-05-07 12:25:18.0  http://twitter.com/fredmontaigu85/statuses/125...  JulietteBinoche|BillGates|RFID.                                              NaN  CNEWS| CNEWS| TF1LeJT| m6info  @cnews s il vous plait @cnews @bfmtv @tf1lejt ...  False                  NaN                   NaN       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA                                  Frédéric FILLATRE                  Vendée  #Patriote #Résistant et #réfractaire ! Villier...            630.0          855.0          11.0          8188.0             680.0  2010-12-29 22:16:46                  NaN                   NaN                      NaN                           NaN       NaN        NaN                NaN        NaN           NaN            NaN                    NaN             NaN  CNEWS plait CNEWS BFMTV Francetele LCI autant ...  POSITIVE  0.728939
# 999   20129  1263164311809273857   20130     Barberis888  Blackrock Le vaccin covid-19 de Bill Gates exi...  2020-05-20 17:46:55.0  http://twitter.com/Barberis888/statuses/126316...                              NaN                          https://t.co/lIGl2N3Uw4                        YouTube  blackrock le vaccin covid 19 de bill gates exi...  False                  NaN                   NaN       NaN        NaN             NaN        NaN     NaN          NaN      NA NA         NA NA  NA NA NA NA NA NA NA NA  <U+271D><U+FE0F>Mima<U+0001F1EB><U+0001F1F7><U...                     NaN  «La France tombera très bas à cause de son org...           9390.0         4198.0         327.0        425789.0           94183.0  2013-02-10 14:51:44                  NaN  youtu.be/qX4E8lzzNk0  https://t.co/lIGl2N3Uw4  https://youtu.be/qX4E8lzzNk0       NaN        NaN                NaN        NaN           NaN            NaN                    NaN             NaN  Blackrock Le vaccin Bill Gates existe depuis p...  POSITIVE  0.642834
#
# [1000 rows x 47 columns]
